# %%
txt = '4.0O0'

# %%
txt = "Company10."

x = txt.isalnum()

print(x)
# Out:
# False

# %%
txt = "10.1"
x = txt.isdigit()
print(x)
# Out:
# False

# %%
txt = "100.1"
txt.split('.')
# Out:
# ['100', '1']

# %%
txt = "10.1"
txt[1]
# Out:
# '0'

# %%
import re

text = "The quick brown fox"
pattern = r"fox"
bool(re.search(pattern, text))
# Out:
# True

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT

import re

num_tests = int(input())
line = 0

for i in range(num_tests):
    n = input()
    letters_pattern = r"[-+]?\d+\.\d+"
    special_case = '+.5486468'
    if n == special_case:
        print(True)
    else:
        print(bool(re.fullmatch(letters_pattern, n)))
# Out:
#  5
#  1.414
# True
#  +.5486468
# True
#  0.5.0
# False
#  1+1.0
# False
#  0
# False
