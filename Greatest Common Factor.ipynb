# %%
import numpy as np
import math

# %% [markdown]
# ## Greatest Common Factor
#
# Write a function that takes a list of integers and returns their greatest common factor.

# %% [markdown]
# My plan for this would be:
# 1. Get the factors of each number.
# 2. Get the common factors of all the numbers
# 3. Return the biggest common factor

# %%
def get_factors(n):
    factors = []
    for num in range(1, n+1):
        if n % num == 0:
            factors.append(num)
    return factors

def get_gcf(nums):
    common_factors = {}

    for idx, num in enumerate(nums):
        factors = get_factors(num)
        common_factors[idx] = factors
    
    return gcf

get_gcf([18, 27])
